# %%
import warnings
warnings.filterwarnings('ignore')
import csv
import pandas as pd

# %%
def get_status(s):
    if s < 16:
        status = "좋음"
    elif s < 36:
        status = "보통"
    elif s < 76:
        status = "나쁨"
    else:
        status = "아주 나쁨"
    return status

# %%
graph_2019 = pd.read_csv("D:\pm2021_01\TeamProject\초미세먼지2019.csv",encoding='euc-kr', engine='python')
graph_2019['2019총평균'] = graph_2019.mean(axis=1)
graph_2019["상태"] = graph_2019["2019총평균"].apply(lambda s: get_status(s))
graph_2019 = graph_2019[["2019총평균","상태"]]

graph_2019
# Out:
#       2019총평균  상태
# 0   24.833333  보통
# 1   21.333333  보통
# 2   22.500000  보통
# 3   23.250000  보통
# 4   23.500000  보통
# 5   22.250000  보통
# 6   20.333333  보통
# 7   25.833333  보통
# 8   26.000000  보통
# 9   21.333333  보통
# 10  28.250000  보통
# 11  25.666667  보통
# 12  25.833333  보통
# 13  19.166667  보통
# 14  20.666667  보통
# 15  18.583333  보통
# 16  18.583333  보통

# %%
graph_2018 = pd.read_csv("D:\pm2021_01\TeamProject\초미세먼지2018.csv",encoding='euc-kr', engine='python')
graph_2018['2018총평균'] = graph_2018.mean(axis=1)
graph_2018["상태"] = graph_2018["2018총평균"].apply(lambda s: get_status(s))
graph_2018 = graph_2018[["2018총평균","상태"]]
graph_2018
# Out:
#     2018총평균  상태
# 0      22.7  보통
# 1      23.5  보통
# 2      22.4  보통
# 3      21.9  보통
# 4      23.6  보통
# 5      21.6  보통
# 6      23.6  보통
# 7      21.8  보통
# 8      24.6  보통
# 9      22.4  보통
# 10     27.0  보통
# 11     21.3  보통
# 12     25.0  보통
# 13     20.5  보통
# 14     24.4  보통
# 15     20.3  보통
# 16     18.7  보통

# %%
graph_2017 = pd.read_csv("D:\pm2021_01\TeamProject\초미세먼지2017.csv",encoding='euc-kr', engine='python')
graph_2017['2017총평균'] = graph_2017.mean(axis=1)
graph_2017["상태"] = graph_2017["2017총평균"].apply(lambda s: get_status(s))
graph_2017 = graph_2017[["2017총평균","상태"]]
graph_2017
# Out:
#       2017총평균  상태
# 0   27.571429  보통
# 1   28.714286  보통
# 2   25.000000  보통
# 3   27.857143  보통
# 4   27.000000  보통
# 5   23.857143  보통
# 6   27.571429  보통
# 7   26.428571  보통
# 8   31.285714  보통
# 9   30.285714  보통
# 10  31.857143  보통
# 11  26.142857  보통
# 12  33.142857  보통
# 13  22.428571  보통
# 14  26.571429  보통
# 15  25.000000  보통
# 16  23.285714  보통

# %%
total_graph2 = pd.concat([graph_2017, graph_2018, graph_2019], axis = 1)
total_graph2
# Out:
#       2017총평균  상태  2018총평균  상태    2019총평균  상태
# 0   27.571429  보통     22.7  보통  24.833333  보통
# 1   28.714286  보통     23.5  보통  21.333333  보통
# 2   25.000000  보통     22.4  보통  22.500000  보통
# 3   27.857143  보통     21.9  보통  23.250000  보통
# 4   27.000000  보통     23.6  보통  23.500000  보통
# 5   23.857143  보통     21.6  보통  22.250000  보통
# 6   27.571429  보통     23.6  보통  20.333333  보통
# 7   26.428571  보통     21.8  보통  25.833333  보통
# 8   31.285714  보통     24.6  보통  26.000000  보통
# 9   30.285714  보통     22.4  보통  21.333333  보통
# 10  31.857143  보통     27.0  보통  28.250000  보통
# 11  26.142857  보통     21.3  보통  25.666667  보통
# 12  33.142857  보통     25.0  보통  25.833333  보통
# 13  22.428571  보통     20.5  보통  19.166667  보통
# 14  26.571429  보통     24.4  보통  20.666667  보통
# 15  25.000000  보통     20.3  보통  18.583333  보통
# 16  23.285714  보통     18.7  보통  18.583333  보통

# %%
fig = plt.figure()
plt.rcParams['figure.figsize'] = (12, 12)
list_1 = ["2017총평균","2018총평균","2019총평균"]

axes1 = fig.add_subplot(2, 3, 1)
axes2 = fig.add_subplot(2, 3, 2)
axes3 = fig.add_subplot(2, 3, 3)
axes4 = fig.add_subplot(2, 3, 4)
axes5 = fig.add_subplot(2, 3, 5)
axes6 = fig.add_subplot(2, 3, 6)

y = []
x = ['2017', '2018','2019']

for i in range(len(list_1)):
    y.append(total_graph2.iloc[0].loc[list_1[i]])

y_1 = []

for i in range(len(list_1)):
    y_1.append(total_graph2.iloc[3].loc[list_1[i]])

y_2 = []

for i in range(len(list_1)):
    y_2.append(total_graph2.iloc[8].loc[list_1[i]])
    
y_3 = []

for i in range(len(list_1)):
    y_3.append(total_graph2.iloc[9].loc[list_1[i]])
               
y_4 = []

for i in range(len(list_1)):
    y_4.append(total_graph2.iloc[10].loc[list_1[i]])

y_5 = []

for i in range(len(list_1)):
    y_5.append(total_graph2.iloc[11].loc[list_1[i]])


axes1.plot(x,y, marker = 'o', color = 'red')
axes2.plot(x,y_1, marker = 'o', color = 'blue')
axes3.plot(x,y_2, marker = 'o', color = 'green')
axes4.plot(x,y_3, marker = 'o', color = 'goldenrod')
axes5.plot(x,y_4, marker = 'o', color = 'darkorange')
axes6.plot(x,y_5, marker = 'o', color = 'cyan')

axes1.set_title('서울')
axes2.set_title('인천')
axes3.set_title('경기')
axes4.set_title('강원')
axes5.set_title('충북')
axes6.set_title('충남')

fig.suptitle('초미세먼지 농도')
fig.tight_layout()

# %%
fig = plt.figure()
plt.rcParams['figure.figsize'] = (12, 12)
list_1 = ["2017총평균","2018총평균","2019총평균"]

axes1 = fig.add_subplot(2, 3, 1)
axes2 = fig.add_subplot(2, 3, 2)
axes3 = fig.add_subplot(2, 3, 3)
axes4 = fig.add_subplot(2, 3, 4)
axes5 = fig.add_subplot(2, 3, 5)
axes6 = fig.add_subplot(2, 3, 6)

y = []
x = ['2017', '2018','2019']

for i in range(len(list_1)):
    y.append(total_graph2.iloc[7].loc[list_1[i]])

y_1 = []

for i in range(len(list_1)):
    y_1.append(total_graph2.iloc[14].loc[list_1[i]])

y_2 = []

for i in range(len(list_1)):
    y_2.append(total_graph2.iloc[5].loc[list_1[i]])
    
y_3 = []

for i in range(len(list_1)):
    y_3.append(total_graph2.iloc[6].loc[list_1[i]])
               
y_4 = []

for i in range(len(list_1)):
    y_4.append(total_graph2.iloc[1].loc[list_1[i]])

y_5 = []

for i in range(len(list_1)):
    y_5.append(total_graph2.iloc[12].loc[list_1[i]])


axes1.plot(x,y, marker = 'o', color = 'red')
axes2.plot(x,y_1, marker = 'o', color = 'blue')
axes3.plot(x,y_2, marker = 'o', color = 'green')
axes4.plot(x,y_3, marker = 'o', color = 'goldenrod')
axes5.plot(x,y_4, marker = 'o', color = 'darkorange')
axes6.plot(x,y_5, marker = 'o', color = 'cyan')

axes1.set_title('세종')
axes2.set_title('경북')
axes3.set_title('대전')
axes4.set_title('울산')
axes5.set_title('부산')
axes6.set_title('전북')

fig.suptitle('초미세먼지 농도')
fig.tight_layout()

# %%
fig = plt.figure()
plt.rcParams['figure.figsize'] = (12, 12)
list_1 = ["2017총평균","2018총평균","2019총평균"]

axes1 = fig.add_subplot(2, 3, 1)
axes2 = fig.add_subplot(2, 3, 2)
axes3 = fig.add_subplot(2, 3, 3)
axes4 = fig.add_subplot(2, 3, 4)
axes5 = fig.add_subplot(2, 3, 5)


y = []
x = ['2017', '2018','2019']

for i in range(len(list_1)):
    y.append(total_graph2.iloc[4].loc[list_1[i]])

y_1 = []

for i in range(len(list_1)):
    y_1.append(total_graph2.iloc[15].loc[list_1[i]])

y_2 = []

for i in range(len(list_1)):
    y_2.append(total_graph2.iloc[13].loc[list_1[i]])
    
y_3 = []

for i in range(len(list_1)):
    y_3.append(total_graph2.iloc[2].loc[list_1[i]])
               
y_4 = []

for i in range(len(list_1)):
    y_4.append(total_graph2.iloc[16].loc[list_1[i]])



axes1.plot(x,y, marker = 'o', color = 'red')
axes2.plot(x,y_1, marker = 'o', color = 'blue')
axes3.plot(x,y_2, marker = 'o', color = 'green')
axes4.plot(x,y_3, marker = 'o', color = 'goldenrod')
axes5.plot(x,y_4, marker = 'o', color = 'darkorange')

axes1.set_title('광주')
axes2.set_title('경남')
axes3.set_title('전남')
axes4.set_title('대구')
axes5.set_title('제주')

fig.suptitle('초미세먼지 농도')
fig.tight_layout()
