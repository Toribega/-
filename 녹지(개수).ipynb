# %%
import warnings
warnings.filterwarnings('ignore')
import csv
import pandas as pd

# %%
graph1= pd.read_csv("D:\pm2021_01\TeamProject\녹지.csv",encoding='euc-kr', engine='python')
graph1
# Out:
#      소재지(시군구)별(1)  소재지(시군구)별(2)     2016     2016.1     2017     2017.1  \
# 0    소재지(시군구)별(1)  소재지(시군구)별(2)        계          계        계          계
# 1    소재지(시군구)별(1)  소재지(시군구)별(2)  시설수 (개)     면적 (㎡)  시설수 (개)     면적 (㎡)
# 2              전국            소계    20748  224053325    21172  236515252
# 3           서울특별시            소계     1039    5013617     1040    5041145
# 4           서울특별시           종로구       32      76901       32      76901
# ..            ...           ...      ...        ...      ...        ...
# 224          경상남도           거창군       40     343043       39     287561
# 225          경상남도           합천군        -          -        -          -
# 226       제주특별자치도            소계      143     718813      132     582075
# 227       제주특별자치도           제주시       86     492588       84     414573
# 228       제주특별자치도          서귀포시       57     226225       48     167502
#
#         2018     2018.1     2019     2019.1
# 0          계          계        계          계
# 1    시설수 (개)     면적 (㎡)  시설수 (개)     면적 (㎡)
# 2      22070  221763854    22585  223209482
# 3       1023    5034732     1017    5028167
# 4         32      76901       32      76901
# ..       ...        ...      ...        ...
# 224       25     275731       25     275731
# 225        3      26740        3      26740
# 226      138     585080      138     585080
# 227       90     417578       90     417578
# 228       48     167502       48     167502
#
# [229 rows x 10 columns]

# %%
# 소계랑 개수만 뽑아오기
graph1 = graph1[['소재지(시군구)별(1)','소재지(시군구)별(2)','2017','2018','2019']]
graph1
# Out:
#      소재지(시군구)별(1)  소재지(시군구)별(2)     2017     2018     2019
# 0    소재지(시군구)별(1)  소재지(시군구)별(2)        계        계        계
# 1    소재지(시군구)별(1)  소재지(시군구)별(2)  시설수 (개)  시설수 (개)  시설수 (개)
# 2              전국            소계    21172    22070    22585
# 3           서울특별시            소계     1040     1023     1017
# 4           서울특별시           종로구       32       32       32
# ..            ...           ...      ...      ...      ...
# 224          경상남도           거창군       39       25       25
# 225          경상남도           합천군        -        3        3
# 226       제주특별자치도            소계      132      138      138
# 227       제주특별자치도           제주시       84       90       90
# 228       제주특별자치도          서귀포시       48       48       48
#
# [229 rows x 5 columns]

# %%
graph2 = graph1.drop(graph1.index[[0,1,2]])
graph2
# Out:
#     소재지(시군구)별(1) 소재지(시군구)별(2)  2017  2018  2019
# 3          서울특별시           소계  1040  1023  1017
# 4          서울특별시          종로구    32    32    32
# 5          서울특별시           중구    26    26    26
# 6          서울특별시          용산구    27    27    27
# 7          서울특별시          성동구    14    14    14
# ..           ...          ...   ...   ...   ...
# 224         경상남도          거창군    39    25    25
# 225         경상남도          합천군     -     3     3
# 226      제주특별자치도           소계   132   138   138
# 227      제주특별자치도          제주시    84    90    90
# 228      제주특별자치도         서귀포시    48    48    48
#
# [226 rows x 5 columns]

# %%
graph2 = graph2.loc[graph2["소재지(시군구)별(2)"]=='소계']
graph2
# Out:
#     소재지(시군구)별(1) 소재지(시군구)별(2)  2017  2018  2019
# 3          서울특별시           소계  1040  1023  1017
# 29         부산광역시           소계   960   958   980
# 32         대구광역시           소계   638   667   666
# 40         인천광역시           소계  1271  1275  1277
# 51         광주광역시           소계    95    96    96
# 57         대전광역시           소계   432   434   434
# 63         울산광역시           소계   551   551   556
# 65       세종특별자치시           소계   290   290   314
# 67           경기도           소계  6380  6836  7010
# 99           강원도           소계   678   676   683
# 118         충청북도           소계  1201  1268  1325
# 130         충청남도           소계  1635  1657  1704
# 146         전라북도           소계   705   699   713
# 160         전라남도           소계  1333  1547  1544
# 183         경상북도           소계  2180  2252  2283
# 207         경상남도           소계  1651  1703  1845
# 226      제주특별자치도           소계   132   138   138

# %%
graph2.drop(['소재지(시군구)별(2)'], axis=1)
# Out:
#     소재지(시군구)별(1)  2017  2018  2019
# 3          서울특별시  1040  1023  1017
# 29         부산광역시   960   958   980
# 32         대구광역시   638   667   666
# 40         인천광역시  1271  1275  1277
# 51         광주광역시    95    96    96
# 57         대전광역시   432   434   434
# 63         울산광역시   551   551   556
# 65       세종특별자치시   290   290   314
# 67           경기도  6380  6836  7010
# 99           강원도   678   676   683
# 118         충청북도  1201  1268  1325
# 130         충청남도  1635  1657  1704
# 146         전라북도   705   699   713
# 160         전라남도  1333  1547  1544
# 183         경상북도  2180  2252  2283
# 207         경상남도  1651  1703  1845
# 226      제주특별자치도   132   138   138

# %%
graph2.dtypes
# Out:
# 소재지(시군구)별(1)    object
# 소재지(시군구)별(2)    object
# 2017            object
# 2018            object
# 2019            object
# dtype: object

# %%
graph2[['2017','2018','2019']] = graph2[['2017','2018','2019']].astype(int)

# %%
from matplotlib import pyplot as plt
import csv
from matplotlib import font_manager, rc

font_name = font_manager.FontProperties(fname = "c:\Windows\Fonts\malgun.ttf").get_name()
rc("font", family=font_name)

# %%
fig = plt.figure()
plt.rcParams['figure.figsize'] = (12,12)
list_1 = ["2017","2018","2019"]

axes1 = fig.add_subplot(2, 3, 1)
axes2 = fig.add_subplot(2, 3, 2)
axes3 = fig.add_subplot(2, 3, 3)
axes4 = fig.add_subplot(2, 3, 4)
axes5 = fig.add_subplot(2, 3, 5)
axes6 = fig.add_subplot(2, 3, 6)

y = []
x = [ '2017', '2018','2019']

for i in range(len(list_1)):
    y.append(graph2.iloc[0].loc[list_1[i]])

y_1 = []

for i in range(len(list_1)):
    y_1.append(graph2.iloc[1].loc[list_1[i]])

y_2 = []

for i in range(len(list_1)):
    y_2.append(graph2.iloc[2].loc[list_1[i]])
    
y_3 = []

for i in range(len(list_1)):
    y_3.append(graph2.iloc[3].loc[list_1[i]])
               
y_4 = []

for i in range(len(list_1)):
    y_4.append(graph2.iloc[4].loc[list_1[i]])

y_5 = []

for i in range(len(list_1)):
    y_5.append(graph2.iloc[5].loc[list_1[i]])


axes1.plot(x,y, marker = 'o', color = 'red')
axes2.plot(x,y_1, marker = 'o', color = 'blue')
axes3.plot(x,y_2, marker = 'o', color = 'green')
axes4.plot(x,y_3, marker = 'o', color = 'goldenrod')
axes5.plot(x,y_4, marker = 'o', color = 'darkorange')
axes6.plot(x,y_5, marker = 'o', color = 'cyan')

axes1.set_title('서울')
axes2.set_title('부산')
axes3.set_title('대구')
axes4.set_title('인천')
axes5.set_title('광주')
axes6.set_title('대전')

fig.suptitle('녹지 시설 개수')
fig.tight_layout()

# %%
fig = plt.figure()
plt.rcParams['figure.figsize'] = (12, 12)
list_1 = ["2017","2018","2019"]

axes1 = fig.add_subplot(2, 3, 1)
axes2 = fig.add_subplot(2, 3, 2)
axes3 = fig.add_subplot(2, 3, 3)
axes4 = fig.add_subplot(2, 3, 4)
axes5 = fig.add_subplot(2, 3, 5)
axes6 = fig.add_subplot(2, 3, 6)

y = []
x = [ '2017', '2018','2019']

for i in range(len(list_1)):
    y.append(graph2.iloc[6].loc[list_1[i]])

y_1 = []

for i in range(len(list_1)):
    y_1.append(graph2.iloc[7].loc[list_1[i]])

y_2 = []

for i in range(len(list_1)):
    y_2.append(graph2.iloc[8].loc[list_1[i]])
    
y_3 = []

for i in range(len(list_1)):
    y_3.append(graph2.iloc[9].loc[list_1[i]])
               
y_4 = []

for i in range(len(list_1)):
    y_4.append(graph2.iloc[10].loc[list_1[i]])

y_5 = []

for i in range(len(list_1)):
    y_5.append(graph2.iloc[11].loc[list_1[i]])


axes1.plot(x,y, marker = 'o', color = 'red')
axes2.plot(x,y_1, marker = 'o', color = 'blue')
axes3.plot(x,y_2, marker = 'o', color = 'green')
axes4.plot(x,y_3, marker = 'o', color = 'goldenrod')
axes5.plot(x,y_4, marker = 'o', color = 'darkorange')
axes6.plot(x,y_5, marker = 'o', color = 'cyan')

axes1.set_title('울산')
axes2.set_title('세종')
axes3.set_title('경기')
axes4.set_title('강원')
axes5.set_title('충북')
axes6.set_title('충남')

fig.suptitle('녹지 시설 개수')
fig.tight_layout()

# %%
fig = plt.figure()
plt.rcParams['figure.figsize'] = (12, 12)
list_1 = ["2017","2018","2019"]

axes1 = fig.add_subplot(2, 3, 1)
axes2 = fig.add_subplot(2, 3, 2)
axes3 = fig.add_subplot(2, 3, 3)
axes4 = fig.add_subplot(2, 3, 4)
axes5 = fig.add_subplot(2, 3, 5)


y = []
x = [ '2017', '2018','2019']

for i in range(len(list_1)):
    y.append(graph2.iloc[12].loc[list_1[i]])

y_1 = []

for i in range(len(list_1)):
    y_1.append(graph2.iloc[13].loc[list_1[i]])

y_2 = []

for i in range(len(list_1)):
    y_2.append(graph2.iloc[14].loc[list_1[i]])
    
y_3 = []

for i in range(len(list_1)):
    y_3.append(graph2.iloc[15].loc[list_1[i]])
               
y_4 = []

for i in range(len(list_1)):
    y_4.append(graph2.iloc[16].loc[list_1[i]])



axes1.plot(x,y, marker = 'o', color = 'red')
axes2.plot(x,y_1, marker = 'o', color = 'blue')
axes3.plot(x,y_2, marker = 'o', color = 'green')
axes4.plot(x,y_3, marker = 'o', color = 'goldenrod')
axes5.plot(x,y_4, marker = 'o', color = 'darkorange')

axes1.set_title('전북')
axes2.set_title('전남')
axes3.set_title('경북')
axes4.set_title('경남')
axes5.set_title('제주')

fig.suptitle('녹지 시설 개수')
fig.tight_layout()
